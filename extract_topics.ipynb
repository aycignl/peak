# %% [markdown]
# # In this script, you can find how to extract features (topics)

# %% [markdown]
# # Import required packages

# %%
import pandas as pd
import numpy as np
import math
from google.colab import drive, files
from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
# "dataset_dir" is the folder which has the Train and Test datasets
# you should create this folder uploading datasets in the repo.
dataset_dir = '/content/drive/My Drive/peak/dataset_dir'

df_train = pd.read_csv(dataset_dir +"/df_train.csv")
df_test = pd.read_csv(dataset_dir +"/df_test.csv")

# %% [markdown]
# # Topic Modeling using Non-negative Matrix Factorization (NMF) <br>
# \begin{equation}
# X \approx W \times H
# \end{equation}
# <BR>
# X: (image, tag), W: (image, topic), H: (topic, tag) matrices <br>
# [sklearn - NMF](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.NMF.html) <br>
# # Term Frequency-Inverse Document Frequency (TF-IDF) <br>
# **Term Frequency:** the number of times a tag appears in an image. <br>
# **Inverse Document Frequency:** total images in Training data over number of images with tag. <br>
# [sklearn TF-IDF](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html) <br>

# %%
# Use TF-IDF to weight tags
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
X = tfidf_vectorizer.fit_transform(df_train.cleaned_tags).toarray()
print("TFIDF's features: ", tfidf_vectorizer.get_feature_names_out())
# Out:
# TFIDF's features:  ['abandoned' 'abbey' 'abdomen' ... 'zoo' 'zoology' 'zoom']

# %%
number_of_topics = 20
nmf_model = NMF(n_components=number_of_topics, init='random', random_state=5)
nmf_features = nmf_model.fit_transform(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/decomposition/_nmf.py:1665: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(

# %%
# Show tags in the Training data with topic-association
components_df = pd.DataFrame(nmf_model.components_, columns = tfidf_vectorizer.get_feature_names_out())
components_df
# Out:
#     abandoned     abbey   abdomen     abend  aboriginal      absorber  \
# 0    0.000000  0.000000  0.000000  0.000293    0.000042  0.000000e+00
# 1    0.000000  0.000000  0.000000  0.000000    0.000000  1.251219e-04
# 2    0.128161  0.006897  0.000000  0.000000    0.000000  0.000000e+00
# 3    0.019752  0.000000  0.000000  0.000000    0.000000  0.000000e+00
# 4    0.000000  0.000000  0.000000  0.000000    0.000000  0.000000e+00
# 5    0.011062  0.000000  0.000000  0.000000    0.000000  0.000000e+00
# 6    0.000000  0.000000  0.000000  0.000000    0.000000  0.000000e+00
# 7    0.000000  0.000000  0.000000  0.001695    0.001386  0.000000e+00
# 8    0.000000  0.000000  0.000000  0.000000    0.000000  0.000000e+00
# 9    0.033212  0.000000  0.004537  0.000159    0.000000  0.000000e+00
# 10   0.000000  0.000000  0.000589  0.000000    0.000087  0.000000e+00
# 11   0.000000  0.000147  0.001759  0.000000    0.000000  9.263138e-07
# 12   0.025273  0.000000  0.000000  0.000956    0.000000  3.784355e-04
# 13   0.000000  0.000000  0.000655  0.000000    0.000000  0.000000e+00
# 14   0.000000  0.000000  0.002016  0.000000    0.000000  0.000000e+00
# 15   0.000000  0.000000  0.000000  0.000000    0.000000  0.000000e+00
# 16   0.040427  0.000000  0.000000  0.000000    0.000000  0.000000e+00
# 17   0.000000  0.000000  0.000000  0.000000    0.000000  0.000000e+00
# 18   0.000000  0.000000  0.000000  0.000000    0.000000  0.000000e+00
# 19   0.000000  0.000000  0.008345  0.000000    0.000120  0.000000e+00
#
#     abstract  abstraction  abundance  academia  ...     young     youth  \
# 0   0.000000     0.000708   0.000000  0.000000  ...  0.000000  0.000000
# 1   0.000000     0.001893   0.000000  0.000000  ...  0.033148  0.000000
# 2   0.000000     0.000622   0.000000  0.000256  ...  0.000000  0.000000
# 3   0.000000     0.000000   0.000000  0.000000  ...  0.000000  0.000000
# 4   0.000000     0.000000   0.000000  0.000000  ...  0.357065  0.000000
# 5   0.000000     0.000000   0.000000  0.000000  ...  0.000000  0.000000
# 6   0.000000     0.000112   0.005800  0.000000  ...  0.018059  0.000000
# 7   0.000000     0.000000   0.003680  0.000000  ...  0.000000  0.000000
# 8   0.008706     0.000000   0.000000  0.000000  ...  0.000000  0.000000
# 9   0.124273     0.000459   0.000000  0.000000  ...  0.000000  0.002936
# 10  0.000000     0.000000   0.000000  0.000000  ...  0.000000  0.014420
# 11  0.021951     0.000000   0.000922  0.000000  ...  0.000000  0.000000
# 12  0.000000     0.001155   0.000000  0.000000  ...  0.000000  0.000000
# 13  0.000000     0.000000   0.000444  0.000000  ...  0.040126  0.034797
# 14  0.000000     0.000000   0.000000  0.000000  ...  0.041812  0.000000
# 15  0.000000     0.001156   0.000000  0.000000  ...  0.000000  0.002171
# 16  0.944191     0.002223   0.000000  0.000095  ...  0.000000  0.000000
# 17  0.090087     0.000155   0.000000  0.000000  ...  0.000000  0.000000
# 18  0.013607     0.000000   0.000000  0.000000  ...  0.000000  0.000000
# 19  0.000000     0.000000   0.000000  0.000000  ...  1.587562  0.004693
#
#        zebra       zen      zion    zip_up    zombie       zoo   zoology  \
# 0   0.000000  0.001678  0.000372  0.000000  0.000000  0.000000  0.000780
# 1   0.000000  0.000000  0.000000  0.000278  0.000000  0.000000  0.000000
# 2   0.000000  0.000571  0.000000  0.000003  0.000000  0.000000  0.000000
# 3   0.000000  0.000174  0.000000  0.000000  0.000000  0.000000  0.000000
# 4   0.000868  0.000000  0.000000  0.000000  0.000000  0.079168  0.005091
# 5   0.000541  0.000000  0.000547  0.000000  0.000000  0.047701  0.002408
# 6   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000039
# 7   0.000000  0.001056  0.000000  0.000000  0.001347  0.000000  0.000000
# 8   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 9   0.000000  0.000000  0.000000  0.000000  0.018919  0.000000  0.000000
# 10  0.000000  0.000000  0.000000  0.000197  0.003645  0.000000  0.000000
# 11  0.000000  0.008040  0.000000  0.000000  0.000000  0.000000  0.000511
# 12  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 13  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 14  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 15  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 16  0.000208  0.002757  0.000000  0.001615  0.001195  0.000000  0.000129
# 17  0.000000  0.000075  0.000066  0.000112  0.000000  0.000000  0.000000
# 18  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 19  0.000000  0.000000  0.000000  0.000346  0.000000  0.000000  0.000000
#
#         zoom
# 0   0.000000
# 1   0.000561
# 2   0.000000
# 3   0.000000
# 4   0.000000
# 5   0.000000
# 6   0.020750
# 7   0.000000
# 8   0.000000
# 9   0.012272
# 10  0.000000
# 11  0.000000
# 12  0.012263
# 13  0.000000
# 14  0.000000
# 15  0.000000
# 16  0.001842
# 17  0.000000
# 18  0.000000
# 19  0.000000
#
# [20 rows x 3994 columns]

# %%
# Show the top 20 most associated tags with topics
individual_topic_dict = {}
for topic in range(components_df.shape[0]):
    tmp = components_df.iloc[topic]
    individual_topic_dict[topic] = list(tmp.nlargest(20).keys())

df_train_topic_tag = pd.DataFrame.from_dict(individual_topic_dict)
df_train_topic_tag
# Out:
#             0            1             2                3          4   \
# 0          sea   recreation  architecture             room     mammal
# 1        beach  competition      building        furniture        pet
# 2        water      leisure          city          indoors     animal
# 3        ocean       motion         urban             seat        dog
# 4     seashore          fun        travel            table       cute
# 5       travel    lifestyle        street            chair     canine
# 6          sky        adult         house  interior_design    looking
# 7         lake        child      outdoors           family        fur
# 8         sand     outdoors           old           window   domestic
# 9     seascape       action          town            house        sit
# 10   landscape       people           sky             home     little
# 11      summer          man     no_person     contemporary        cat
# 12       river         wear        window             lamp      puppy
# 13    vacation          boy       tourism           museum      funny
# 14      nature         girl      daylight    trading_floor   portrait
# 15        rock      uniform         light           inside        eye
# 16      island        woman     cityscape             wood     kitten
# 17    outdoors       helmet         tower             desk      young
# 18  reflection  adolescence          home       exhibition  no_person
# 19      sunset      athlete          wall             sofa      sleep
#
#               5              6               7                    8   \
# 0           park       business           group              concert
# 1         nature     technology        festival          performance
# 2           wood           text        religion             musician
# 3           tree       internet          battle               singer
# 4       outdoors       computer           crowd                 band
# 5      landscape          paper          street                stage
# 6         summer        indoors         offense                music
# 7    environment      telephone       drag_race             festival
# 8          grass       industry             man               guitar
# 9           fall          facts          police           instrument
# 10      daylight       commerce     celebration            guitarist
# 11       outside         symbol        commerce  stringed_instrument
# 12          leaf  communication            city            pop_music
# 13    relaxation           data          people                light
# 14       leisure      no_person          market                 jazz
# 15     no_person         office  group_together               energy
# 16        travel          money             war           microphone
# 17  fair_weather   illustration           woman               people
# 18      wildlife     horizontal           adult                  man
# 19      vertical         number      exhibition                adult
#
#                  9                  10         11                     12  \
# 0        monochrome               wear     flower  transportation_system
# 1              dark                man      flora                vehicle
# 2              nude           portrait       leaf                   road
# 3             model              adult     garden                    car
# 4              face  facial_expression      color                 street
# 5   black_and_white              music     bright                  wheel
# 6            studio              woman     floral                traffic
# 7               art             people    closeup                 action
# 8           profile            indoors     growth                 travel
# 9               eye             outfit     summer                  drive
# 10             girl              movie      petal                   race
# 11            adult           musician   blooming                   fast
# 12        side_view               girl     nature               industry
# 13            woman              child  beautiful                  hurry
# 14         portrait                lid  no_person                   city
# 15           people              actor       food                    bus
# 16              man            fashion     season                railway
# 17           shadow         monochrome    desktop                   bike
# 18          fashion              group       love               accident
# 19             blur                sit   delicate             automotive
#
#            13                 14              15            16            17  \
# 0        baby       togetherness  administration        design        sunset
# 1         son          enjoyment        election       desktop          dawn
# 2       child         friendship          leader           art       evening
# 3      little             family          league  illustration           sun
# 4   innocence  facial_expression         meeting         retro          dusk
# 5     toddler              child      politician      abstract         light
# 6         fun          happiness       education       pattern           sky
# 7        cute               love         banking    decoration    silhouette
# 8         toy         adolescent          school       texture     landscape
# 9        girl              woman        business       vintage       backlit
# 10        joy                fun            room         color           fog
# 11     family     group_together           adult        symbol  fair_weather
# 12  happiness           laughing           group           old          moon
# 13   portrait                man       democracy       graphic    reflection
# 14        boy            indoors           chair        vector         water
# 15      smile          education       furniture         paper          dark
# 16      funny              group        congress      painting     no_person
# 17     people            leisure          soccer     no_person        nature
# 18       face              adult            home         image          tree
# 19   cheerful              table          people         shape          lake
#
#                 18         19
# 0             snow    fashion
# 1             cold     pretty
# 2           winter      model
# 3              ice       sexy
# 4            frost    glamour
# 5          weather  beautiful
# 6           frozen      young
# 7             tree       girl
# 8           season       hair
# 9        snowstorm      woman
# 10       landscape   portrait
# 11          frosty       cute
# 12            wood        eye
# 13            icee       face
# 14       no_person    elegant
# 15          nature      dress
# 16  frosty_weather     people
# 17             fog       lips
# 18        outdoors     person
# 19           storm       skin

# %% [markdown]
# # Predict Topic Distributions of Test Data

# %%
# Transform the TF-IDF
X_test = tfidf_vectorizer.transform(df_test.cleaned_tags)
nmf_features_test = nmf_model.transform(X_test)
pd.DataFrame(nmf_features_test)
# Out:
#             0         1         2         3         4         5         6   \
# 0     0.000000  0.000000  0.003894  0.004360  0.000000  0.021853  0.008524
# 1     0.000000  0.000000  0.000000  0.000701  0.000000  0.000000  0.000000
# 2     0.000000  0.001332  0.021806  0.000000  0.000000  0.000000  0.000000
# 3     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4     0.000323  0.000000  0.000000  0.048821  0.000072  0.000000  0.000000
# ...        ...       ...       ...       ...       ...       ...       ...
# 4995  0.000000  0.000000  0.000000  0.000000  0.000835  0.002024  0.000932
# 4996  0.000000  0.000000  0.000000  0.000000  0.000000  0.163886  0.000000
# 4997  0.068881  0.000000  0.087164  0.000000  0.000000  0.000873  0.040323
# 4998  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4999  0.036439  0.000000  0.040545  0.000000  0.000000  0.129757  0.000000
#
#             7         8         9         10        11        12        13  \
# 0     0.000000  0.000000  0.000000  0.077317  0.000000  0.000000  0.000000
# 1     0.008343  0.000000  0.000000  0.076507  0.000000  0.000000  0.000000
# 2     0.000000  0.000000  0.016424  0.111895  0.000000  0.117735  0.044491
# 3     0.000000  0.000000  0.050547  0.105778  0.000000  0.000000  0.000000
# 4     0.000000  0.000000  0.000000  0.028621  0.000000  0.000000  0.006318
# ...        ...       ...       ...       ...       ...       ...       ...
# 4995  0.000000  0.000000  0.000000  0.000000  0.002136  0.168007  0.000000
# 4996  0.000000  0.000000  0.000000  0.000000  0.109700  0.000000  0.000000
# 4997  0.014768  0.000000  0.000000  0.000000  0.000000  0.085690  0.000280
# 4998  0.000000  0.000000  0.028616  0.000000  0.026094  0.000000  0.000000
# 4999  0.000000  0.001979  0.000000  0.000000  0.026541  0.000000  0.000000
#
#             14        15        16        17        18        19
# 0     0.151370  0.005432  0.000000  0.000000  0.000000  0.003094
# 1     0.147227  0.056369  0.000000  0.000000  0.000000  0.000000
# 2     0.000000  0.000000  0.000000  0.004922  0.000000  0.000000
# 3     0.000000  0.000000  0.000000  0.000000  0.000000  0.022150
# 4     0.000000  0.000000  0.039204  0.000000  0.000415  0.005294
# ...        ...       ...       ...       ...       ...       ...
# 4995  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4996  0.000000  0.000000  0.000000  0.028264  0.014342  0.000000
# 4997  0.000000  0.004548  0.000000  0.000000  0.000000  0.000037
# 4998  0.006354  0.000000  0.068457  0.148388  0.000000  0.000000
# 4999  0.000000  0.000000  0.000000  0.000000  0.017557  0.000000
#
# [5000 rows x 20 columns]

# %%
# Prepare input files for the training and the test
train_input = pd.DataFrame(nmf_features).to_numpy()
test_input = pd.DataFrame(nmf_features_test).to_numpy()

train_label = np.array(df_train.normalizedpublic)
train_label = np.array(list(map(lambda x: math.floor(x), train_label)))
test_label = np.array(df_test.normalizedpublic)

train_input.shape, test_input.shape, train_label.shape, test_label.shape
# Out:
# ((27000, 20), (5000, 20), (27000,), (5000,))
